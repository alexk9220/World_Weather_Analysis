# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
weather_api_key = "d8d060d60bac212f5c4a285a87c43bd4"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d8d060d60bac212f5c4a285a87c43bd4

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hastings
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | urengoy
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | caloundra
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | lavrentiya
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | hun
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | ixtepec
# Processing Record 17 of Set 1 | avera
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | zaraysk
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | vao
# Processing Record 24 of Set 1 | huntington beach
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | laguna
# Processing Record 28 of Set 1 | fairbanks
# Processing Record 29 of Set 1 | mizan teferi
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | ippy
# Processing Record 35 of Set 1 | gladstone
# Processing Record 36 of Set 1 | burica
# City not found. Skipping...
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | linares
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 1 | fougamou
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | korla
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | okhotsk
# Processing Record 50 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | nishihara
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | sao lourenco do sul
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | sinnamary
# Processing Record 9 of Set 2 | teya
# Processing Record 10 of Set 2 | novoye atlashevo
# City not found. Skipping...
# Processing Record 11 of Set 2 | tsaratanana
# Processing Record 12 of Set 2 | barybino
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | moa
# Processing Record 15 of Set 2 | sao felix do xingu
# Processing Record 16 of Set 2 | polson
# Processing Record 17 of Set 2 | lufilufi
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | kracheh
# City not found. Skipping...
# Processing Record 21 of Set 2 | marsabit
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | yar-sale
# Processing Record 25 of Set 2 | challapata
# Processing Record 26 of Set 2 | verkhoyansk
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | basar
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | faya
# Processing Record 32 of Set 2 | alexandria
# Processing Record 33 of Set 2 | margate
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | kinsale
# Processing Record 36 of Set 2 | kindberg
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | hambantota
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | tual
# Processing Record 42 of Set 2 | pacifica
# Processing Record 43 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | great falls
# Processing Record 47 of Set 2 | half moon bay
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | geghamasar
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | san rafael del sur
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | young
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | broome
# Processing Record 9 of Set 3 | minbu
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | rypefjord
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | aybak
# City not found. Skipping...
# Processing Record 17 of Set 3 | fuling
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | kenora
# Processing Record 21 of Set 3 | la ronge
# Processing Record 22 of Set 3 | novovarshavka
# Processing Record 23 of Set 3 | kisesa
# Processing Record 24 of Set 3 | tres arroyos
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | lompoc
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | olafsvik
# Processing Record 33 of Set 3 | xining
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | fort nelson
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | pevek
# Processing Record 40 of Set 3 | salzgitter
# Processing Record 41 of Set 3 | faanui
# Processing Record 42 of Set 3 | waingapu
# Processing Record 43 of Set 3 | natal
# Processing Record 44 of Set 3 | tabuk
# Processing Record 45 of Set 3 | vila velha
# Processing Record 46 of Set 3 | kyren
# Processing Record 47 of Set 3 | kailua
# Processing Record 48 of Set 3 | bulungu
# Processing Record 49 of Set 3 | turayf
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | yulara
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | swellendam
# Processing Record 4 of Set 4 | hualmay
# Processing Record 5 of Set 4 | fayaoue
# Processing Record 6 of Set 4 | sfantu gheorghe
# Processing Record 7 of Set 4 | hinatuan
# Processing Record 8 of Set 4 | mehamn
# Processing Record 9 of Set 4 | portsmouth
# Processing Record 10 of Set 4 | kaa-khem
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | kaisiadorys
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | kropotkin
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | chulman
# Processing Record 17 of Set 4 | uusikaupunki
# Processing Record 18 of Set 4 | ambovombe
# Processing Record 19 of Set 4 | schotten
# Processing Record 20 of Set 4 | berlevag
# Processing Record 21 of Set 4 | asau
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | sola
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | voi
# Processing Record 28 of Set 4 | kuandian
# Processing Record 29 of Set 4 | krasnozerskoye
# Processing Record 30 of Set 4 | mahebourg
# Processing Record 31 of Set 4 | labuhan
# Processing Record 32 of Set 4 | shingu
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | tacna
# Processing Record 35 of Set 4 | port augusta
# Processing Record 36 of Set 4 | radlje ob dravi
# Processing Record 37 of Set 4 | sao gabriel da cachoeira
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | alice springs
# Processing Record 40 of Set 4 | saint-louis
# Processing Record 41 of Set 4 | areka
# Processing Record 42 of Set 4 | red bluff
# Processing Record 43 of Set 4 | ridgecrest
# Processing Record 44 of Set 4 | tsogni
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | ornskoldsvik
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | verkhnevilyuysk
# Processing Record 50 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | pringsewu
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 5 | santarem
# Processing Record 8 of Set 5 | chicama
# Processing Record 9 of Set 5 | kiunga
# Processing Record 10 of Set 5 | iquitos
# Processing Record 11 of Set 5 | gazojak
# Processing Record 12 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 5 | babu
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | hithadhoo
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | puerto leguizamo
# Processing Record 20 of Set 5 | tessalit
# Processing Record 21 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 22 of Set 5 | gama
# Processing Record 23 of Set 5 | keta
# Processing Record 24 of Set 5 | wiang sa
# Processing Record 25 of Set 5 | arrifes
# Processing Record 26 of Set 5 | eureka
# Processing Record 27 of Set 5 | cap malheureux
# Processing Record 28 of Set 5 | la baule-escoublac
# Processing Record 29 of Set 5 | mokrous
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | narsaq
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | kaeo
# Processing Record 35 of Set 5 | ust-tsilma
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | taltal
# Processing Record 40 of Set 5 | olinda
# Processing Record 41 of Set 5 | ribeira grande
# Processing Record 42 of Set 5 | umm lajj
# Processing Record 43 of Set 5 | loandjili
# Processing Record 44 of Set 5 | steinbach
# Processing Record 45 of Set 5 | ust-kuyga
# Processing Record 46 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 5 | bundaberg
# Processing Record 48 of Set 5 | pacific grove
# Processing Record 49 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | fare
# Processing Record 2 of Set 6 | nocupetaro
# Processing Record 3 of Set 6 | phan thiet
# Processing Record 4 of Set 6 | bonao
# Processing Record 5 of Set 6 | banjar
# Processing Record 6 of Set 6 | farrukhnagar
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | butaritari
# Processing Record 9 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 6 | georgetown
# Processing Record 11 of Set 6 | monywa
# Processing Record 12 of Set 6 | ovsyanka
# Processing Record 13 of Set 6 | kabala
# Processing Record 14 of Set 6 | chake chake
# Processing Record 15 of Set 6 | san cristobal
# Processing Record 16 of Set 6 | beringovskiy
# Processing Record 17 of Set 6 | saravan
# Processing Record 18 of Set 6 | jalu
# Processing Record 19 of Set 6 | abha
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | huarmey
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | oudtshoorn
# Processing Record 24 of Set 6 | coahuayana
# Processing Record 25 of Set 6 | tonota
# Processing Record 26 of Set 6 | kodinsk
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | sorong
# Processing Record 29 of Set 6 | santo antonio do sudoeste
# Processing Record 30 of Set 6 | nantucket
# Processing Record 31 of Set 6 | totness
# Processing Record 32 of Set 6 | sambava
# Processing Record 33 of Set 6 | muyezerskiy
# Processing Record 34 of Set 6 | griffith
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | prudy
# Processing Record 37 of Set 6 | marzuq
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | vestmannaeyjar
# Processing Record 40 of Set 6 | linjiang
# Processing Record 41 of Set 6 | beira
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | merauke
# Processing Record 45 of Set 6 | port elizabeth
# Processing Record 46 of Set 6 | bulgan
# Processing Record 47 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | ulaangom
# Processing Record 50 of Set 6 | boca do acre
# Processing Record 1 of Set 7 | formosa
# Processing Record 2 of Set 7 | sonamura
# Processing Record 3 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | provideniya
# Processing Record 6 of Set 7 | soyo
# Processing Record 7 of Set 7 | ayan
# Processing Record 8 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 7 | vyazma
# Processing Record 10 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 7 | shelopugino
# Processing Record 12 of Set 7 | svetlaya
# Processing Record 13 of Set 7 | jubayl
# City not found. Skipping...
# Processing Record 14 of Set 7 | palafrugell
# Processing Record 15 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 16 of Set 7 | udarnyy
# Processing Record 17 of Set 7 | markova
# Processing Record 18 of Set 7 | breyten
# Processing Record 19 of Set 7 | sanary-sur-mer
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | flinders
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | hovd
# Processing Record 24 of Set 7 | eufaula
# Processing Record 25 of Set 7 | poum
# Processing Record 26 of Set 7 | lipovtsy
# Processing Record 27 of Set 7 | longyearbyen
# Processing Record 28 of Set 7 | ongandjera
# Processing Record 29 of Set 7 | palpa
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | alekseyevsk
# Processing Record 32 of Set 7 | riyadh
# Processing Record 33 of Set 7 | kijang
# Processing Record 34 of Set 7 | marawi
# Processing Record 35 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 7 | maniitsoq
# Processing Record 37 of Set 7 | nanortalik
# Processing Record 38 of Set 7 | orange
# Processing Record 39 of Set 7 | arima
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | lubsko
# Processing Record 42 of Set 7 | bud
# Processing Record 43 of Set 7 | erenhot
# Processing Record 44 of Set 7 | saquarema
# Processing Record 45 of Set 7 | malakal
# Processing Record 46 of Set 7 | biak
# Processing Record 47 of Set 7 | ziarat
# Processing Record 48 of Set 7 | marica
# Processing Record 49 of Set 7 | lodja
# Processing Record 50 of Set 7 | geraldton
# Processing Record 1 of Set 8 | carbonia
# Processing Record 2 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 8 | awjilah
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 8 | kupang
# Processing Record 7 of Set 8 | sikasso
# Processing Record 8 of Set 8 | nelson bay
# Processing Record 9 of Set 8 | ketchikan
# Processing Record 10 of Set 8 | turukhansk
# Processing Record 11 of Set 8 | walvis bay
# Processing Record 12 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 8 | keti bandar
# Processing Record 14 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 8 | luohe
# Processing Record 17 of Set 8 | havre-saint-pierre
# Processing Record 18 of Set 8 | ngorongoro
# Processing Record 19 of Set 8 | la antigua
# Processing Record 20 of Set 8 | ozernovskiy
# Processing Record 21 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 22 of Set 8 | arkhangelsk
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | benguela
# Processing Record 25 of Set 8 | saint-pierre
# Processing Record 26 of Set 8 | cabo san lucas
# Processing Record 27 of Set 8 | vysokogornyy
# Processing Record 28 of Set 8 | santa rosa
# Processing Record 29 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 8 | ahipara
# Processing Record 31 of Set 8 | san ignacio
# Processing Record 32 of Set 8 | san patricio
# Processing Record 33 of Set 8 | cedar falls
# Processing Record 34 of Set 8 | shaowu
# Processing Record 35 of Set 8 | orbetello
# Processing Record 36 of Set 8 | esmeraldas
# Processing Record 37 of Set 8 | shwebo
# Processing Record 38 of Set 8 | nabire
# Processing Record 39 of Set 8 | byron bay
# Processing Record 40 of Set 8 | sioux lookout
# Processing Record 41 of Set 8 | sassandra
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | inca
# Processing Record 45 of Set 8 | pisco
# Processing Record 46 of Set 8 | pincher creek
# Processing Record 47 of Set 8 | socol
# Processing Record 48 of Set 8 | comodoro rivadavia
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | ponta delgada
# Processing Record 2 of Set 9 | port lincoln
# Processing Record 3 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 9 | ibirapitanga
# Processing Record 5 of Set 9 | college
# Processing Record 6 of Set 9 | zhanaozen
# Processing Record 7 of Set 9 | padang
# Processing Record 8 of Set 9 | pionerskiy
# Processing Record 9 of Set 9 | stepnyak
# Processing Record 10 of Set 9 | airai
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | piacabucu
# Processing Record 13 of Set 9 | dingle
# Processing Record 14 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 9 | bathsheba
# Processing Record 16 of Set 9 | horqueta
# Processing Record 17 of Set 9 | pilar
# Processing Record 18 of Set 9 | lakselv
# Processing Record 19 of Set 9 | minden
# Processing Record 20 of Set 9 | hay river
# Processing Record 21 of Set 9 | moree
# Processing Record 22 of Set 9 | dire dawa
# Processing Record 23 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 27 of Set 9 | lockhart
# Processing Record 28 of Set 9 | tazovskiy
# Processing Record 29 of Set 9 | vinh
# Processing Record 30 of Set 9 | batemans bay
# Processing Record 31 of Set 9 | iralaya
# Processing Record 32 of Set 9 | thunder bay
# Processing Record 33 of Set 9 | imphal
# Processing Record 34 of Set 9 | beeskow
# Processing Record 35 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 36 of Set 9 | ambilobe
# Processing Record 37 of Set 9 | solnechnyy
# Processing Record 38 of Set 9 | onega
# Processing Record 39 of Set 9 | bubaque
# Processing Record 40 of Set 9 | mount isa
# Processing Record 41 of Set 9 | ambon
# Processing Record 42 of Set 9 | manikchhari
# City not found. Skipping...
# Processing Record 43 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 9 | kawalu
# Processing Record 45 of Set 9 | moussoro
# Processing Record 46 of Set 9 | umea
# Processing Record 47 of Set 9 | charleston
# Processing Record 48 of Set 9 | thai nguyen
# Processing Record 49 of Set 9 | turtas
# Processing Record 50 of Set 9 | sobolevo
# Processing Record 1 of Set 10 | dubai
# Processing Record 2 of Set 10 | juazeiro
# Processing Record 3 of Set 10 | porto novo
# Processing Record 4 of Set 10 | barentin
# Processing Record 5 of Set 10 | brest
# Processing Record 6 of Set 10 | teguldet
# Processing Record 7 of Set 10 | batagay
# Processing Record 8 of Set 10 | pangody
# Processing Record 9 of Set 10 | jardim
# Processing Record 10 of Set 10 | champerico
# Processing Record 11 of Set 10 | vila
# Processing Record 12 of Set 10 | tyumentsevo
# Processing Record 13 of Set 10 | dori
# Processing Record 14 of Set 10 | vesele
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | jizan
# Processing Record 17 of Set 10 | lasa
# Processing Record 18 of Set 10 | lorengau
# Processing Record 19 of Set 10 | panaba
# Processing Record 20 of Set 10 | nazca
# Processing Record 21 of Set 10 | kokuy
# Processing Record 22 of Set 10 | cayenne
# Processing Record 23 of Set 10 | peikang
# City not found. Skipping...
# Processing Record 24 of Set 10 | gimli
# Processing Record 25 of Set 10 | del rio
# Processing Record 26 of Set 10 | kemin
# Processing Record 27 of Set 10 | vestmanna
# Processing Record 28 of Set 10 | santiago
# Processing Record 29 of Set 10 | thurles
# Processing Record 30 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 31 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 10 | mount gambier
# Processing Record 33 of Set 10 | broken hill
# Processing Record 34 of Set 10 | xuddur
# Processing Record 35 of Set 10 | madera
# Processing Record 36 of Set 10 | rocha
# Processing Record 37 of Set 10 | wukari
# Processing Record 38 of Set 10 | araouane
# Processing Record 39 of Set 10 | tecoanapa
# Processing Record 40 of Set 10 | vulcan
# Processing Record 41 of Set 10 | tshikapa
# Processing Record 42 of Set 10 | la orilla
# Processing Record 43 of Set 10 | tutoia
# Processing Record 44 of Set 10 | port blair
# Processing Record 45 of Set 10 | tibati
# Processing Record 46 of Set 10 | perth
# Processing Record 47 of Set 10 | bad munstereifel
# Processing Record 48 of Set 10 | samarai
# Processing Record 49 of Set 10 | mindelo
# Processing Record 50 of Set 10 | nyurba
# Processing Record 1 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 11 | burgeo
# Processing Record 3 of Set 11 | nichinan
# Processing Record 4 of Set 11 | kudahuvadhoo
# Processing Record 5 of Set 11 | sulangan
# Processing Record 6 of Set 11 | suhbaatar
# Processing Record 7 of Set 11 | haicheng
# Processing Record 8 of Set 11 | saint-augustin
# Processing Record 9 of Set 11 | palmeiras de goias
# Processing Record 10 of Set 11 | genhe
# Processing Record 11 of Set 11 | fort-shevchenko
# Processing Record 12 of Set 11 | naze
# Processing Record 13 of Set 11 | cordoba
# Processing Record 14 of Set 11 | lumeje
# Processing Record 15 of Set 11 | hof
# Processing Record 16 of Set 11 | oxapampa
# Processing Record 17 of Set 11 | graaff-reinet
# Processing Record 18 of Set 11 | farafangana
# Processing Record 19 of Set 11 | inverell
# Processing Record 20 of Set 11 | diego de almagro
# Processing Record 21 of Set 11 | bijie
# Processing Record 22 of Set 11 | gizo
# Processing Record 23 of Set 11 | arlit
# Processing Record 24 of Set 11 | launceston
# Processing Record 25 of Set 11 | tolaga bay
# Processing Record 26 of Set 11 | enid
# Processing Record 27 of Set 11 | nueva loja
# Processing Record 28 of Set 11 | wahpeton
# Processing Record 29 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 11 | sulam
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | tukrah
# Processing Record 33 of Set 11 | balaipungut
# Processing Record 34 of Set 11 | ereymentau
# Processing Record 35 of Set 11 | qaqortoq
# Processing Record 36 of Set 11 | bethanien
# Processing Record 37 of Set 11 | coquimbo
# Processing Record 38 of Set 11 | alto piquiri
# Processing Record 39 of Set 11 | mandalgovi
# Processing Record 40 of Set 11 | adre
# Processing Record 41 of Set 11 | anzhero-sudzhensk
# Processing Record 42 of Set 11 | jumla
# Processing Record 43 of Set 11 | omsukchan
# Processing Record 44 of Set 11 | boende
# Processing Record 45 of Set 11 | killybegs
# Processing Record 46 of Set 11 | galveston
# Processing Record 47 of Set 11 | adrar
# Processing Record 48 of Set 11 | alamosa
# Processing Record 49 of Set 11 | aconibe
# Processing Record 50 of Set 11 | paracuru
# Processing Record 1 of Set 12 | coolum beach
# Processing Record 2 of Set 12 | marsh harbour
# Processing Record 3 of Set 12 | lishan
# Processing Record 4 of Set 12 | evensk
# Processing Record 5 of Set 12 | cacu
# Processing Record 6 of Set 12 | thinadhoo
# Processing Record 7 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 12 | asuncion
# Processing Record 10 of Set 12 | kemlya
# Processing Record 11 of Set 12 | ugoofaaru
# Processing Record 12 of Set 12 | churumuco
# City not found. Skipping...
# Processing Record 13 of Set 12 | kosh-agach
# Processing Record 14 of Set 12 | pandoh
# Processing Record 15 of Set 12 | kendari
# Processing Record 16 of Set 12 | cervo
# Processing Record 17 of Set 12 | kieta
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | xihe
# Processing Record 20 of Set 12 | ryki
# Processing Record 21 of Set 12 | warren
# Processing Record 22 of Set 12 | makakilo city
# Processing Record 23 of Set 12 | hervey bay
# Processing Record 24 of Set 12 | mukhen
# Processing Record 25 of Set 12 | port alberni
# Processing Record 26 of Set 12 | lloydminster
# Processing Record 27 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 28 of Set 12 | pemba
# Processing Record 29 of Set 12 | sindor
# Processing Record 30 of Set 12 | tilichiki
# Processing Record 31 of Set 12 | oranjemund
# Processing Record 32 of Set 12 | brownfield
# Processing Record 33 of Set 12 | bani
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | dunedin
# Processing Record 36 of Set 12 | sikandra
# Processing Record 37 of Set 12 | tiarei
# Processing Record 38 of Set 12 | semporna
# Processing Record 39 of Set 12 | abalak
# Processing Record 40 of Set 12 | kisangani
# Processing Record 41 of Set 12 | turkistan
# Processing Record 42 of Set 12 | santa marta
# Processing Record 43 of Set 12 | port pirie
# Processing Record 44 of Set 12 | gorontalo
# Processing Record 45 of Set 12 | bilibino
# Processing Record 46 of Set 12 | mana
# Processing Record 47 of Set 12 | plaeng yao
# Processing Record 48 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 12 | arrecife
# Processing Record 50 of Set 12 | plainview
# Processing Record 1 of Set 13 | puerto el triunfo
# Processing Record 2 of Set 13 | castelfranco veneto
# Processing Record 3 of Set 13 | karratha
# Processing Record 4 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 13 | puerto carreno
# Processing Record 6 of Set 13 | panama city
# Processing Record 7 of Set 13 | leshukonskoye
# Processing Record 8 of Set 13 | port hardy
# Processing Record 9 of Set 13 | talaya
# Processing Record 10 of Set 13 | brigantine
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | katha
# City not found. Skipping...
# Processing Record 13 of Set 13 | klaksvik
# Processing Record 14 of Set 13 | tongliao
# Processing Record 15 of Set 13 | tokur
# Processing Record 16 of Set 13 | zapolyarnyy
# Processing Record 17 of Set 13 | nyimba
# Processing Record 18 of Set 13 | candido mendes
# Processing Record 19 of Set 13 | nyaunglebin
# Processing Record 20 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 13 | grand gaube
# Processing Record 22 of Set 13 | mananara
# Processing Record 23 of Set 13 | labrea
# Processing Record 24 of Set 13 | siguiri
# Processing Record 25 of Set 13 | saint george
# Processing Record 26 of Set 13 | peniche
# Processing Record 27 of Set 13 | buala
# Processing Record 28 of Set 13 | sapa
# Processing Record 29 of Set 13 | bac lieu
# Processing Record 30 of Set 13 | hulan ergi
# Processing Record 31 of Set 13 | zambezi
# Processing Record 32 of Set 13 | si satchanalai
# Processing Record 33 of Set 13 | morondava
# Processing Record 34 of Set 13 | alta floresta
# Processing Record 35 of Set 13 | windhoek
# Processing Record 36 of Set 13 | capelinha
# Processing Record 37 of Set 13 | barreiras
# Processing Record 38 of Set 13 | niceville
# Processing Record 39 of Set 13 | malayal
# Processing Record 40 of Set 13 | rundu
# Processing Record 41 of Set 13 | kangaatsiaq
# Processing Record 42 of Set 13 | kokopo
# Processing Record 43 of Set 13 | itoman
# Processing Record 44 of Set 13 | roma
# Processing Record 45 of Set 13 | shu
# Processing Record 46 of Set 13 | dicabisagan
# Processing Record 47 of Set 13 | bani walid
# Processing Record 48 of Set 13 | kirakira
# Processing Record 49 of Set 13 | fujieda
# Processing Record 50 of Set 13 | surt
# Processing Record 1 of Set 14 | gainesville
# Processing Record 2 of Set 14 | kokstad
# Processing Record 3 of Set 14 | rochelle
# Processing Record 4 of Set 14 | touros
# Processing Record 5 of Set 14 | nurota
# Processing Record 6 of Set 14 | mariinsk
# Processing Record 7 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 8 of Set 14 | yashkul
# Processing Record 9 of Set 14 | kuhestan
# City not found. Skipping...
# Processing Record 10 of Set 14 | surin
# Processing Record 11 of Set 14 | knysna
# Processing Record 12 of Set 14 | aakirkeby
# City not found. Skipping...
# Processing Record 13 of Set 14 | mancio lima
# Processing Record 14 of Set 14 | vicuna
# Processing Record 15 of Set 14 | luganville
# Processing Record 16 of Set 14 | ojinaga
# Processing Record 17 of Set 14 | rostaq
# City not found. Skipping...
# Processing Record 18 of Set 14 | asyut
# Processing Record 19 of Set 14 | shar
# Processing Record 20 of Set 14 | kahului
# Processing Record 21 of Set 14 | hazaribag
# Processing Record 22 of Set 14 | berdigestyakh
# Processing Record 23 of Set 14 | westport
# Processing Record 24 of Set 14 | videira
# Processing Record 25 of Set 14 | zeya
# Processing Record 26 of Set 14 | king city
# Processing Record 27 of Set 14 | kutum
# Processing Record 28 of Set 14 | vostok
# Processing Record 29 of Set 14 | yaroslavl
# Processing Record 30 of Set 14 | ondjiva
# Processing Record 31 of Set 14 | aksum
# Processing Record 32 of Set 14 | cozumel
# Processing Record 33 of Set 14 | beloha
# Processing Record 34 of Set 14 | atherton
# Processing Record 35 of Set 14 | eirunepe
# Processing Record 36 of Set 14 | olga
# Processing Record 37 of Set 14 | bria
# Processing Record 38 of Set 14 | omboue
# Processing Record 39 of Set 14 | usinsk
# Processing Record 40 of Set 14 | rize
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | atka
# City not found. Skipping...
# Processing Record 43 of Set 14 | malm
# Processing Record 44 of Set 14 | praia da vitoria
# Processing Record 45 of Set 14 | tura
# Processing Record 46 of Set 14 | la palma
# Processing Record 47 of Set 14 | amahai
# Processing Record 48 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 49 of Set 14 | antibes
# Processing Record 50 of Set 14 | sault sainte marie
# Processing Record 1 of Set 15 | mantua
# Processing Record 2 of Set 15 | udachnyy
# Processing Record 3 of Set 15 | skoghall
# Processing Record 4 of Set 15 | manali
# Processing Record 5 of Set 15 | san andres
# Processing Record 6 of Set 15 | colwyn bay
# Processing Record 7 of Set 15 | englehart
# Processing Record 8 of Set 15 | karasburg
# Processing Record 9 of Set 15 | jacqueville
# Processing Record 10 of Set 15 | mayskiy
# Processing Record 11 of Set 15 | mingshui
# Processing Record 12 of Set 15 | dubbo
# Processing Record 13 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 14 of Set 15 | pasinler
# Processing Record 15 of Set 15 | moron
# Processing Record 16 of Set 15 | torbat-e jam
# Processing Record 17 of Set 15 | sawankhalok
# Processing Record 18 of Set 15 | batagay-alyta
# Processing Record 19 of Set 15 | ous
# Processing Record 20 of Set 15 | honningsvag
# Processing Record 21 of Set 15 | panacan
# Processing Record 22 of Set 15 | skibbereen
# Processing Record 23 of Set 15 | whitehorse
# Processing Record 24 of Set 15 | bambui
# Processing Record 25 of Set 15 | ankazoabo
# Processing Record 26 of Set 15 | dwarka
# Processing Record 27 of Set 15 | acapulco
# Processing Record 28 of Set 15 | rancho palos verdes
# Processing Record 29 of Set 15 | swan hill
# Processing Record 30 of Set 15 | teeli
# Processing Record 31 of Set 15 | bacungan
# Processing Record 32 of Set 15 | mawlaik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Hastings  50.86    0.57     41.00        77         100        8.01
# 1        Hilo  19.73 -155.09     73.40        73          75        4.70
# 2   Busselton -33.65  115.33     64.26        54          34       11.48
# 3     Urengoy  65.97   78.37     10.18        95           0        9.98
# 4    Cherskiy  68.75  161.30    -12.03        90          89        8.59
# 5   Caloundra -26.80  153.13     81.00        82           0        8.01
# 6       Kapaa  22.08 -159.32     71.60        83          40        8.05
# 7     Rikitea -23.12 -134.97     75.74        76          95       11.59
# 8  Lavrentiya  65.58 -171.00     12.13        90          62       13.65
# 9       Tiksi  71.69  128.87      2.08        87         100       38.30
#
#   Current Description Country                 Date
# 0     overcast clouds      GB  2020-12-01 07:28:41
# 1       broken clouds      US  2020-12-01 07:28:41
# 2    scattered clouds      AU  2020-12-01 07:28:41
# 3           clear sky      RU  2020-12-01 07:28:41
# 4     overcast clouds      RU  2020-12-01 07:28:42
# 5           clear sky      AU  2020-12-01 07:28:42
# 6    scattered clouds      US  2020-12-01 07:24:55
# 7     overcast clouds      PF  2020-12-01 07:28:42
# 8       broken clouds      RU  2020-12-01 07:28:42
# 9     overcast clouds      RU  2020-12-01 07:28:42

# %%
df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
df = df[new_column_order]
df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Hastings      GB  50.86    0.57     41.00        77         100
# 1        Hilo      US  19.73 -155.09     73.40        73          75
# 2   Busselton      AU -33.65  115.33     64.26        54          34
# 3     Urengoy      RU  65.97   78.37     10.18        95           0
# 4    Cherskiy      RU  68.75  161.30    -12.03        90          89
# 5   Caloundra      AU -26.80  153.13     81.00        82           0
# 6       Kapaa      US  22.08 -159.32     71.60        83          40
# 7     Rikitea      PF -23.12 -134.97     75.74        76          95
# 8  Lavrentiya      RU  65.58 -171.00     12.13        90          62
# 9       Tiksi      RU  71.69  128.87      2.08        87         100
#
#    Wind Speed Current Description
# 0        8.01     overcast clouds
# 1        4.70       broken clouds
# 2       11.48    scattered clouds
# 3        9.98           clear sky
# 4        8.59     overcast clouds
# 5        8.01           clear sky
# 6        8.05    scattered clouds
# 7       11.59     overcast clouds
# 8       13.65       broken clouds
# 9       38.30     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"

df.to_csv(output_data_file, index_label="City_ID")
